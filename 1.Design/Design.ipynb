# %% [markdown]
# I need to predict which map any two teams are likely to pick and ban
#
# The data has
# |Tournament|stage|match type|Match name|Team|Action|map|
# |---|---|---|---|---|---|---|
# |what tournament the game is played in|Which stage of the tournament the game is in|Which stage of the stage the game is in|Team vs Team|Team picking|ban or pick|map selected|

# %% [markdown]
# tournament is useless
#
# Stage us useless
#
# Match type is useless
#
# Match name need to be split along the vs to find both teams and their rivalerys
#
# team is needed to attach an id to everything
#
# action needed to lassify if the map is a bn or a pick
#
# map needs to be id'ed
#
# In summary the graph will plot the probability of each map being picked and another graph of each map being banned

# %% [markdown]
# Step 1: create a table for each team and show their picks and bans for each map

# %% [markdown]
# A person will select two teams from a list, and the ai will calculate the probability of the bans and picks for each team

# %% [markdown]
# the output should be a probability of each map for their two bans and one pick.
#
# most likely will want to multiply the chances of picks that appeared in previous matches with the same teams, when compared with the normal maps picked as some teams have specific bad maps that other teams will pick

# %% [markdown]
# Model will take 1 Team  and predict what maps they will most likely pick
